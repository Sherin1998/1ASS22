# %%
# 1
X='Ineuron'
def func():
    print(X)
func()

#The function takes X which is a global variable.Since global variables can be accessed by all functions,X gets printed inside the function
# Out:
# Ineuron

# %% [markdown]
# #2
# X='Ineuron'
# def func():
#     X='NI!'
#
#
# func()
# print(X)
#
# Here X='Ineuron'is a global variable and X='NI!' is local variable.The scope of local variable is defined inside the function which defines it.As print is outside the function,global X is printed

# %% [markdown]
# #3
# X='Ineuron'
# def func():
#     X='NI!'
#     print(X)
#
#
# func()
# print(X)
#
# Here X='Ineuron'is a global variable and X='NI!' is local variable.The scope of local variable is defined inside the function which defines,so 'NI!'is printed inside the function .X defined outside the function will be printed for the 2nd print statement.

# %% [markdown]
# #4
# X='Ineuron'
# def func():
#     global X
#     X='NI!'
#
# func()
# print(X)
#
# This function uses the keyword global which explicitly makes the variable global although it is defined inside the function.Thus the X='NI!' has global scope and is printed outside the function body

# %% [markdown]
# #5
# X='Ineuron'
# def func():
#     X='NI!'
#     def nested():
#         print(X)
#     nested()
#
# func()
# X
# This function has a nested() function inside func().Since X='NI!' has local scope it is utilized by nested function.The X in the main function uses the X='Ineuron' which has global scope

# %% [markdown]
# #6
# def func():
#     X='NI!'
#     def nested():
#         nonlocal X
#         X='Spam'
#     nested()
#     print(X)
#
# func()
#
# nonlocal keyword is used in nested functions. The nested function has a nonlocal keyword which replaces the outer function X='NI!' and assigns X='Spam' and gets printed.
